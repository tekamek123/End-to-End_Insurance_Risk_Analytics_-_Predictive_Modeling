# %% [markdown]
# # Task 1: Exploratory Data Analysis (EDA)
# ## Insurance Risk Analytics & Predictive Modeling
#
# This notebook performs comprehensive EDA on the insurance claim data to:
# - Understand data structure and quality
# - Discover patterns in risk and profitability
# - Answer key business questions
# - Prepare for hypothesis testing and modeling

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings

from src.data_loader import load_insurance_data, prepare_data_for_analysis
from src.utils import calculate_loss_ratio, detect_outliers_iqr, get_data_summary

warnings.filterwarnings('ignore')

# Set plotting style
try:
    plt.style.use('seaborn-v0_8-darkgrid')
except OSError:
    try:
        plt.style.use('seaborn-darkgrid')
    except OSError:
        plt.style.use('ggplot')
sns.set_palette("husl")

# %matplotlib inline

# %% [markdown]
# ## 2. Load Data
#
# Note: Use `sample_size` parameter for faster initial exploration. Remove it to use the full dataset.

# %%
# Load data (use sample_size parameter for faster initial exploration)
# Remove sample_size to use full dataset
df = load_insurance_data(sample_size=50000)  # Adjust as needed
df = prepare_data_for_analysis(df)

print(f"Data shape: {df.shape}")
print(f"Date range: {df['TransactionMonth'].min()} to {df['TransactionMonth'].max()}")
# Out:
# Loading data from: D:\My Projects\Kifiya AI Mastery Training\week3\notebooks\..\data\MachineLearningRating_v3.txt
# Loaded 1,000,098 rows and 52 columns
# Sampled to 50,000 rows
# Data shape: (50000, 56)
# Date range: 2013-10-01 00:00:00 to 2015-08-01 00:00:00

# %% [markdown]
# ## 3. Run Full EDA
#
# You can run the complete EDA pipeline using the InsuranceEDA class:

# %%
from src.eda import InsuranceEDA

# Initialize and run full EDA
eda = InsuranceEDA()
eda.run_full_eda()
# Out:
# ================================================================================
# INSURANCE RISK ANALYTICS - EXPLORATORY DATA ANALYSIS
# ================================================================================
# Loading data from: D:\My Projects\Kifiya AI Mastery Training\week3\notebooks\..\data\MachineLearningRating_v3.txt
# Loaded 1,000,098 rows and 52 columns
#
# Data shape: (1000098, 56)
# Date range: 2013-10-01 00:00:00 to 2015-08-01 00:00:00
#
# ================================================================================
# RUNNING COMPLETE EDA PIPELINE
# ================================================================================
#
# ================================================================================
# 1. DATA SUMMARIZATION
# ================================================================================
#
# 1.1 Data Structure:
#    - Total rows: 1,000,098
#    - Total columns: 56
#
# 1.2 Data Types:
#    - object: 34 columns
#    - float64: 13 columns
#    - int64: 4 columns
#    - int32: 2 columns
#    - datetime64[ns]: 1 columns
#    - bool: 1 columns
#    - period[M]: 1 columns
#
# 1.3 Descriptive Statistics (Numerical Variables):
#        TotalPremium  TotalClaims   SumInsured  CustomValueEstimate  \
# count    1000098.00   1000098.00   1000098.00            220456.00
# mean          61.91        64.86    604172.73            225531.13
# std          230.28      2384.07   1508331.84            564515.75
# min         -782.58    -12002.41         0.01             20000.00
# 25%            0.00         0.00      5000.00            135000.00
# 50%            2.18         0.00      7500.00            220000.00
# 75%           21.93         0.00    250000.00            280000.00
# max        65282.60    393092.11  12636200.00          26550000.00
#
#        CalculatedPremiumPerTerm
# count                1000098.00
# mean                     117.88
# std                      399.70
# min                        0.00
# 25%                        3.22
# 50%                        8.44
# 75%                       90.00
# max                    74422.17
#
# 1.4 Variability Measures (Coefficient of Variation):
#    - TotalPremium: CV = 371.99%
#    - TotalClaims: CV = 3675.66%
#    - SumInsured: CV = 249.65%
#    - CustomValueEstimate: CV = 250.31%
#    - CalculatedPremiumPerTerm: CV = 339.09%
#
# ================================================================================
# 2. DATA QUALITY ASSESSMENT
# ================================================================================
#
# 2.1 Missing Values:
#                  Column  MissingCount  MissingPercentage
# NumberOfVehiclesInFleet       1000098             100.00
#             CrossBorder        999400              99.93
#     CustomValueEstimate        779642              77.96
#               Converted        641901              64.18
#                 Rebuilt        641901              64.18
#              WrittenOff        641901              64.18
#               LossRatio        381634              38.16
#              NewVehicle        153295              15.33
#                    Bank        145961              14.59
#             AccountType         40232               4.02
#                  Gender          9536               0.95
#           MaritalStatus          8259               0.83
#           NumberOfDoors           552               0.06
#                bodytype           552               0.06
#               kilowatts           552               0.06
#           cubiccapacity           552               0.06
#               Cylinders           552               0.06
#                   Model           552               0.06
#                    make           552               0.06
#        VehicleIntroDate           552               0.06
#
# 2.2 Duplicate Rows: 0 (0.00%)
#
# ================================================================================
# 3. UNIVARIATE ANALYSIS
# ================================================================================
#
# 3.1 Saved: univariate_numerical_distributions.png
# 3.2 Saved: univariate_categorical_distributions.png
#
# ================================================================================
# 4. BIVARIATE & MULTIVARIATE ANALYSIS
# ================================================================================
#
# 4.1 Saved: correlation_matrix.png
# 4.2 Saved: monthly_trends.png
# 4.3 Saved: premium_vs_claims_by_province.png
#
# ================================================================================
# 5. OUTLIER DETECTION
# ================================================================================
#
# 5.1 Saved: outlier_detection_boxplots.png
#
# ================================================================================
# 6. ANSWERING GUIDING QUESTIONS
# ================================================================================
#
# Q1. Overall Loss Ratio: 1.0477 (104.77%)
#    - Total Premium: ZAR 61,911,562.70
#    - Total Claims: ZAR 64,867,546.17
#
# Q1a. Loss Ratio by Province:
#                LossRatio
# Province
# Gauteng           1.2220
# KwaZulu-Natal     1.0827
# Western Cape      1.0595
# North West        0.7904
# Mpumalanga        0.7209
# Free State        0.6808
# Limpopo           0.6612
# Eastern Cape      0.6338
# Northern Cape     0.2827
#
# Q1b. Loss Ratio by VehicleType:
#                    LossRatio
# VehicleType
# Heavy Commercial      1.6281
# Medium Commercial     1.0503
# Passenger Vehicle     1.0482
# Light Commercial      0.2321
# Bus                   0.1373
#
# Q1c. Loss Ratio by Gender:
#                LossRatio
# Gender
# Not specified     1.0593
# Male              0.8839
# Female            0.8219
#
# Q2. Key Financial Variables - Outlier Summary:
#    - TotalClaims: 2,793 outliers (0.28%)
#    - CustomValueEstimate: 1,785 outliers (0.81%)
#
# Q3. Temporal Trends:
#    YearMonth  PolicyID  TotalPremium   TotalClaims  LossRatio
# 17   2015-03      5186  6.002282e+06  7.474981e+06   1.245357
# 18   2015-04      5468  6.500269e+06  9.076825e+06   1.396377
# 19   2015-05      5605  6.400050e+06  6.963110e+06   1.087977
# 20   2015-06      5778  6.737930e+06  6.204182e+06   0.920785
# 21   2015-07      5864  7.026171e+06  6.751214e+06   0.960867
# 22   2015-08      5820  7.281043e+06  1.019819e+06   0.140065
#
# Q4. Top Vehicle Makes by Total Claims:
#                  TotalClaims  TotalPremium  LossRatio
# make
# TOYOTA          5.174611e+07  4.994567e+07   1.036048
# MERCEDES-BENZ   2.938695e+06  2.764734e+06   1.062922
# VOLKSWAGEN      1.839180e+06  1.416877e+06   1.298052
# CMC             1.323616e+06  9.574460e+05   1.382444
# GOLDEN JOURNEY  1.246583e+06  1.462989e+06   0.852079
# AUDI            1.021004e+06  3.762743e+05   2.713456
# IVECO           7.558930e+05  5.261262e+05   1.436714
# C.A.M           6.957082e+05  6.075631e+05   1.145080
# BMW             4.814972e+05  2.427652e+05   1.983386
# HYUNDAI         4.533079e+05  1.136156e+05   3.989840
#
# ================================================================================
# 7. CREATIVE VISUALIZATIONS
# ================================================================================
#
# 7.1 Saved: creative_viz1_loss_ratio_heatmap.png
# 7.2 Saved: creative_viz2_risk_return_province.png
# 7.3 Saved: creative_viz3_temporal_evolution.png
#
# ================================================================================
# EDA COMPLETE!
# All visualizations saved to: D:\My Projects\Kifiya AI Mastery Training\week3\notebooks\..\outputs\figures
# ================================================================================
